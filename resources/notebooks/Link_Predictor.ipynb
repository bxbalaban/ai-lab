# %%
# !pip install rdflib torch_geometric
# Out:
# Collecting rdflib
#   Downloading rdflib-7.1.4-py3-none-any.whl.metadata (11 kB)
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib) (3.2.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.6.15)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.1.2->aiohttp->torch_geometric) (4.14.1)
# Downloading rdflib-7.1.4-py3-none-any.whl (565 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 18.1 MB/s eta 0:00:00
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 50.4 MB/s eta 0:00:00
# Installing collected packages: rdflib, torch_geometric
# Successfully installed rdflib-7.1.4 torch_geometric-2.6.1

# %%
import os
import torch
import torch.nn.functional as F
from torch import nn
from torch_geometric.data import Data
from torch_geometric.nn import RGCNConv
from torch_geometric.utils import negative_sampling
import rdflib
from rdflib.namespace import Namespace, RDF
from shapely import wkt
import glob
import random
import re
import requests
from sklearn.metrics import precision_score
from rdflib.namespace import NamespaceManager

# %%
OWNER = "bxbalaban"
REPO = "ai-lab"
BRANCH = "db0c4603d6b5b78929720437b2bbf93ede6ff6b6"
FOLDER_PATH = "data"

os.makedirs("ttl_files", exist_ok=True)

api_url = f"https://api.github.com/repos/{OWNER}/{REPO}/contents/{FOLDER_PATH}?ref={BRANCH}"

response = requests.get(api_url)
response.raise_for_status()
files = response.json()

ttl_files = [f for f in files if f["name"].endswith(".ttl")]

print(f"Found {len(ttl_files)} TTL files.")

for file_info in ttl_files:
    download_url = file_info["download_url"]
    filename = file_info["name"]
    print(f"Downloading {filename} ...")
    r = requests.get(download_url)
    r.raise_for_status()
    with open(os.path.join("ttl_files", filename), "wb") as f:
        f.write(r.content)

print("All TTL files downloaded to ./ttl_files/")

# %%
BOTAI = Namespace("http://www.aiLab.org/botAiLab#")
GEO = Namespace("http://www.opengis.net/ont/geosparql#")
LOCAL = Namespace("http://example.org/building/")

class GeoLinkPredictor(nn.Module):
    def __init__(self, in_channels, hidden_channels=128, num_relations=3):
        super().__init__()
        self.conv1 = RGCNConv(in_channels, hidden_channels, num_relations)
        self.conv2 = RGCNConv(hidden_channels, hidden_channels, num_relations)
        self.classifier = nn.Sequential(
            nn.Linear(hidden_channels * 2, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def encode(self, x, edge_index, edge_type):
        x = self.conv1(x, edge_index, edge_type).relu()
        x = self.conv2(x, edge_index, edge_type)
        return x

    def decode(self, z, edge_index):
        src, dst = edge_index
        z_cat = torch.cat([z[src], z[dst]], dim=1)
        return self.classifier(z_cat).view(-1)

def parse_ttl_to_pyg(ttl_path):
    g = rdflib.Graph()
    g.parse(ttl_path, format="turtle")
    g.bind("botAiLab", BOTAI)
    g.bind("geo", GEO)

    nodes = list(set(g.subjects()))
    node_idx = {n: i for i, n in enumerate(nodes)}
    num_nodes = len(nodes)

    features = torch.zeros((num_nodes, 7))  # x, y, z, w, h, d, rot

    for s in nodes:
        loc = g.value(s, BOTAI.hasLocation)
        if loc:
            try:
                coords = list(map(float, str(loc).split(",")))
                if len(coords) == 3:
                    x, y, z = coords
                    wkt_str = f"POINT Z({x} {y} {z})"
                    g.add((s, GEO.asWKT, rdflib.Literal(wkt_str, datatype=GEO.wktLiteral)))
            except:
                continue

    for s in nodes:
        i = node_idx[s]
        loc = g.value(s, GEO.asWKT)
        if loc:
            pt = wkt.loads(str(loc))
            features[i][:3] = torch.tensor([pt.x, pt.y, pt.z if hasattr(pt, 'z') else 0.0])

        size = g.value(s, BOTAI.hasSize)
        if size:
            try:
                w, h, d = map(float, str(size).split(","))
                features[i][3:6] = torch.tensor([w, h, d])
            except:
                pass

        rot = g.value(s, BOTAI.hasRotation)
        if rot:
            try:
                features[i][6] = float(str(rot))
            except:
                pass

    relation_uris = [
        BOTAI.isBelow,
        BOTAI.isAbove,
        BOTAI.intersectsElement
    ]
    relation_to_id = {rel: i for i, rel in enumerate(relation_uris)}

    edge_list = []
    edge_types = []

    for rel in relation_uris:
        for s, _, o in g.triples((None, rel, None)):
            if s in node_idx and o in node_idx:
                edge_list.append([node_idx[s], node_idx[o]])
                edge_types.append(relation_to_id[rel])

    if not edge_list:
        edge_index = torch.empty((2, 0), dtype=torch.long)
        edge_type = torch.empty((0,), dtype=torch.long)
    else:
        edge_index = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
        edge_type = torch.tensor(edge_types, dtype=torch.long)

    pos_edges = [
        [node_idx[s], node_idx[o]]
        for s, o in g.subject_objects(BOTAI.supports)
        if s in node_idx and o in node_idx
    ]
    if not pos_edges:
        raise ValueError(f"No supports links found in {ttl_path}")
    pos_edge_index = torch.tensor(pos_edges, dtype=torch.long).t().contiguous()

    neg_edge_index = negative_sampling(
        edge_index=pos_edge_index,
        num_nodes=num_nodes,
        num_neg_samples=pos_edge_index.size(1)
    )

    return Data(
        x=features,
        edge_index=edge_index,
        edge_type=edge_type,
        pos_edge_index=pos_edge_index,
        neg_edge_index=neg_edge_index
    )

def train(model, data, optimizer):
    model.train()
    optimizer.zero_grad()
    z = model.encode(data.x, data.edge_index, data.edge_type)
    pos_score = model.decode(z, data.pos_edge_index)
    neg_score = model.decode(z, data.neg_edge_index)

    pos_loss = F.binary_cross_entropy_with_logits(pos_score, torch.ones_like(pos_score))
    neg_loss = F.binary_cross_entropy_with_logits(neg_score, torch.zeros_like(neg_score))
    loss = pos_loss + neg_loss
    loss.backward()
    optimizer.step()

    return loss.item()

def main(data_folder, epochs=100):
    ttl_files = glob.glob(os.path.join(data_folder, "*.ttl"))

    filtered_files = []
    for f in ttl_files:
        filename = os.path.basename(f)
        match = re.search(r'(\d+)\.ttl$', filename)
        if match:
            num = int(match.group(1))
            if 1 <= num <= 100:
                filtered_files.append(f)

    all_graphs = [parse_ttl_to_pyg(f) for f in filtered_files]

    model = GeoLinkPredictor(in_channels=7, num_relations=3)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    for epoch in range(1, epochs + 1):
        total_loss = 0
        for graph in all_graphs:
            loss = train(model, graph, optimizer)
            total_loss += loss
        print(f"Epoch {epoch} - Loss: {total_loss:.4f}")

    torch.save(model.state_dict(), "link_predictor_model.pt")
    print("✅ Model saved to link_predictor_model.pt")

if __name__ == "__main__":
    main(data_folder="/content/ttl_files")
# Out:
# Epoch 1 - Loss: 93.3739
# Epoch 2 - Loss: 44.2668
# Epoch 3 - Loss: 30.8922
# Epoch 4 - Loss: 13.9436
# Epoch 5 - Loss: 11.3858
# Epoch 6 - Loss: 15.4037
# Epoch 7 - Loss: 13.0172
# Epoch 8 - Loss: 4.7113
# Epoch 9 - Loss: 2.4407
# Epoch 10 - Loss: 3.0299
# Epoch 11 - Loss: 3.0503
# Epoch 12 - Loss: 14.1825
# Epoch 13 - Loss: 10.5297
# Epoch 14 - Loss: 10.4829
# Epoch 15 - Loss: 9.7007
# Epoch 16 - Loss: 2.1221
# Epoch 17 - Loss: 0.4639
# Epoch 18 - Loss: 0.2470
# Epoch 19 - Loss: 0.3337
# Epoch 20 - Loss: 1.1374
# Epoch 21 - Loss: 8.3989
# Epoch 22 - Loss: 4.6798
# Epoch 23 - Loss: 1.9266
# Epoch 24 - Loss: 14.3127
# Epoch 25 - Loss: 33.3637
# Epoch 26 - Loss: 2.6864
# Epoch 27 - Loss: 0.9530
# Epoch 28 - Loss: 0.4776
# Epoch 29 - Loss: 0.0930
# Epoch 30 - Loss: 0.0697
# Epoch 31 - Loss: 0.0537
# Epoch 32 - Loss: 0.0437
# Epoch 33 - Loss: 0.0364
# Epoch 34 - Loss: 0.0308
# Epoch 35 - Loss: 0.0265
# Epoch 36 - Loss: 0.0229
# Epoch 37 - Loss: 0.0200
# Epoch 38 - Loss: 0.0175
# Epoch 39 - Loss: 0.0153
# Epoch 40 - Loss: 0.0135
# Epoch 41 - Loss: 0.0119
# Epoch 42 - Loss: 0.0105
# Epoch 43 - Loss: 0.0093
# Epoch 44 - Loss: 0.0082
# Epoch 45 - Loss: 0.0072
# Epoch 46 - Loss: 0.0064
# Epoch 47 - Loss: 0.0056
# Epoch 48 - Loss: 0.0050
# Epoch 49 - Loss: 0.0044
# Epoch 50 - Loss: 0.0039
# Epoch 51 - Loss: 0.0034
# Epoch 52 - Loss: 0.0030
# Epoch 53 - Loss: 0.0027
# Epoch 54 - Loss: 0.0024
# Epoch 55 - Loss: 0.0021
# Epoch 56 - Loss: 0.0019
# Epoch 57 - Loss: 0.0016
# Epoch 58 - Loss: 0.0014
# Epoch 59 - Loss: 0.0013
# Epoch 60 - Loss: 0.0011
# Epoch 61 - Loss: 0.0010
# Epoch 62 - Loss: 0.0009
# Epoch 63 - Loss: 0.0008
# Epoch 64 - Loss: 0.0007
# Epoch 65 - Loss: 0.0006
# Epoch 66 - Loss: 0.0006
# Epoch 67 - Loss: 0.0005
# Epoch 68 - Loss: 0.0005
# Epoch 69 - Loss: 0.0004
# Epoch 70 - Loss: 0.0004
# Epoch 71 - Loss: 0.0003
# Epoch 72 - Loss: 0.0003
# Epoch 73 - Loss: 0.0003
# Epoch 74 - Loss: 0.0002
# Epoch 75 - Loss: 0.0002
# Epoch 76 - Loss: 0.0002
# Epoch 77 - Loss: 0.0002
# Epoch 78 - Loss: 0.0001
# Epoch 79 - Loss: 0.0001
# Epoch 80 - Loss: 0.0001
# Epoch 81 - Loss: 0.0001
# Epoch 82 - Loss: 0.0001
# Epoch 83 - Loss: 0.0001
# Epoch 84 - Loss: 0.0001
# Epoch 85 - Loss: 0.0001
# Epoch 86 - Loss: 0.0001
# Epoch 87 - Loss: 0.0000
# Epoch 88 - Loss: 0.0000
# Epoch 89 - Loss: 0.0000
# Epoch 90 - Loss: 0.0000
# Epoch 91 - Loss: 0.0000
# Epoch 92 - Loss: 0.0000
# Epoch 93 - Loss: 0.0000
# Epoch 94 - Loss: 0.0000
# Epoch 95 - Loss: 0.0000
# Epoch 96 - Loss: 0.0000
# Epoch 97 - Loss: 0.0000
# Epoch 98 - Loss: 78.4441
# Epoch 99 - Loss: 3.6062
# Epoch 100 - Loss: 2.5196
# ✅ Model saved to link_predictor_model.pt

# %%
def load_graph_for_inference(ttl_file):
    g = rdflib.Graph()
    g.parse(ttl_file, format="turtle")
    g.bind("botAiLab", BOTAI)
    g.bind("geo", GEO)

    nodes = list(set(g.subjects()))
    node_index = {n: i for i, n in enumerate(nodes)}
    index_node = {i: n for n, i in node_index.items()}
    num_nodes = len(nodes)

    features = torch.zeros((num_nodes, 7))  # x, y, z, w, h, d, rot

    for s in nodes:
        loc = g.value(s, BOTAI.hasLocation)
        if loc:
            try:
                coords = list(map(float, str(loc).split(",")))
                if len(coords) == 3:
                    x, y, z = coords
                    wkt_str = f"POINT Z({x} {y} {z})"
                    g.add((s, GEO.asWKT, rdflib.Literal(wkt_str, datatype=GEO.wktLiteral)))
            except:
                continue

    for s in nodes:
        i = node_index[s]
        loc = g.value(s, GEO.asWKT)
        if loc:
            pt = wkt.loads(str(loc))
            features[i][:3] = torch.tensor([pt.x, pt.y, pt.z if hasattr(pt, 'z') else 0.0])

        size = g.value(s, BOTAI.hasSize)
        if size:
            try:
                w, h, d = map(float, str(size).split(","))
                features[i][3:6] = torch.tensor([w, h, d])
            except:
                pass

        rot = g.value(s, BOTAI.hasRotation)
        if rot:
            try:
                features[i][6] = float(str(rot))
            except:
                pass

    relation_uris = [
        BOTAI.adjacentElement,
        BOTAI.isAbove,
        BOTAI.intersectsElement
    ]

    relation_to_id = {rel: i for i, rel in enumerate(relation_uris)}

    edge_list = []
    edge_types = []

    for rel in relation_uris:
        for s, _, o in g.triples((None, rel, None)):
            if s in node_index and o in node_index:
                edge_list.append([node_index[s], node_index[o]])
                edge_types.append(relation_to_id[rel])

    if not edge_list:
        edge_index = torch.empty((2, 0), dtype=torch.long)
        edge_type = torch.empty((0,), dtype=torch.long)
    else:
        edge_index = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
        edge_type = torch.tensor(edge_types, dtype=torch.long)

    supports = set()
    for s, _, o in g.triples((None, BOTAI.supports, None)):
        if s in node_index and o in node_index:
            supports.add((node_index[s], node_index[o]))

    return features, edge_index, supports, node_index, index_node, edge_type

# %%
def predict_missing_links(ttl_file, model_path, top_k=10):
    original_graph = rdflib.Graph()
    original_graph.parse(ttl_file, format="turtle")

    test_graph = rdflib.Graph()
    test_graph += original_graph
    botAiLab = Namespace("http://www.aiLab.org/botAiLab#")
    supports_triples = list(test_graph.triples((None, botAiLab.supports, None)))

    for triple in supports_triples:
        test_graph.remove(triple)

    temp_ttl_path = "temp_inference.ttl"
    test_graph.serialize(temp_ttl_path, format="turtle")

    x, edge_index, _ , node_index, index_node, edge_type = load_graph_for_inference(temp_ttl_path)

    model = GeoLinkPredictor(in_channels=7)
    model.load_state_dict(torch.load(model_path, map_location=torch.device("cpu")))
    model.eval()

    with torch.no_grad():
        z = model.encode(x, edge_index, edge_type)

        num_nodes = x.size(0)
        candidate_edges = []
        candidate_labels = []
        for i in range(num_nodes):
            for j in range(num_nodes):
                if i != j:
                    subj = rdflib.URIRef(index_node[i])
                    obj = rdflib.URIRef(index_node[j])
                    candidate_edges.append((i, j))
                    label = (subj, botAiLab.supports, obj) in original_graph
                    candidate_labels.append(label)

        if not candidate_edges:
            print("✅ No candidate missing links to predict.")
            return

        edge_tensor = torch.tensor(candidate_edges, dtype=torch.long).t()
        scores = torch.sigmoid(model.decode(z, edge_tensor))

        top_scores, top_indices = torch.topk(scores, min(top_k, len(scores)))
        filtered_scores = []
        filtered_indices = []
        for i, score in enumerate(top_scores):
            if score >= 0.9:
                filtered_scores.append(score)
                filtered_indices.append(top_indices[i])

        predicted_links = [candidate_edges[idx] for idx in filtered_indices]
        predicted_labels = [candidate_labels[idx] for idx in filtered_indices]


        print(f"📊 Top {top_k} predicted missing `botAiLab:supports` links:")
        for score, (i, j), is_correct in zip(filtered_scores, predicted_links, predicted_labels):
            subj_uri = rdflib.URIRef(index_node[i])
            obj_uri = rdflib.URIRef(index_node[j])
            status = "✅" if is_correct else "❌"
            print(f"{status} {subj_uri} → {obj_uri} | score={score:.4f}")
            original_graph.add((subj_uri, botAiLab.supports, obj_uri))

        folder = os.path.dirname(ttl_file)
        filename = os.path.basename(ttl_file)
        enriched_path = os.path.join(folder, f"enriched_{filename}")

        namespace_manager = NamespaceManager(original_graph)
        namespace_manager.bind("local", LOCAL)
        original_graph.namespace_manager = namespace_manager
        original_graph.serialize(destination=enriched_path, format="turtle")

        accuracy = sum(predicted_labels) / len(predicted_labels)
        print(f"\n Accuracy of top-{top_k} predictions: {accuracy:.2%}")
        return accuracy

# %%
def predict_missing_links_in_folder(folder_path, model_path, top_k=50):
    ttl_files = glob.glob(os.path.join(folder_path, "*.ttl"))

    filtered_files = []
    for f in ttl_files:
        filename = os.path.basename(f)
        match = re.search(r'^building(\d+)\.ttl$', filename)
        if match:
            num = int(match.group(1))
            if 1 <= num <= 100:
                filtered_files.append(f)

    if not filtered_files:
        print("🚫 No TTL files found in the folder.")
        return
    all_acc = []
    for ttl_file in filtered_files:
        full_path = os.path.join(folder_path, ttl_file)
        print(f"\n🔍 Processing: {ttl_file}")
        try:
            acc = predict_missing_links(
                ttl_file=full_path,
                model_path=model_path,
                top_k=top_k
            )
            all_acc.append(acc)
        except Exception as e:
            print(f"⚠️ Failed to process {ttl_file}: {e}")

    print(f"Average Acc: {sum(all_acc)/len(all_acc):.4f}")

# %%
predict_missing_links_in_folder(
    folder_path="/content/ttl_files",
    model_path="/content/link_predictor_model.pt",
    top_k=15
)
# Out:
# 🔍 Processing: /content/ttl_files/building46.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9999
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building62.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9997
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9994
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building64.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9995
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9994
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9989
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9989
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9986
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building22.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_2_wall_2 → http://example.org/building/roof_slab | score=0.9926
# ✅ http://example.org/building/storey_2_column_3 → http://example.org/building/roof_slab | score=0.9879
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building72.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9997
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9997
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9995
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9990
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9988
# ✅ http://example.org/building/storey_2_wall_2 → http://example.org/building/roof_slab | score=0.9951
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/roof_slab | score=0.9934
# ✅ http://example.org/building/storey_2_wall_3 → http://example.org/building/roof_slab | score=0.9933
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/roof_slab | score=0.9932
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/roof_slab | score=0.9883
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building53.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/roof_slab | score=0.9998
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=0.9998
# ✅ http://example.org/building/storey_3_column_2 → http://example.org/building/roof_slab | score=0.9998
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=0.9997
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=0.9996
# ❌ http://example.org/building/storey_2_column_3 → http://example.org/building/roof_slab | score=0.9995
# ❌ http://example.org/building/storey_2_column_4 → http://example.org/building/roof_slab | score=0.9908
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9391
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9116
#
#  Accuracy of top-15 predictions: 77.78%
#
# 🔍 Processing: /content/ttl_files/building67.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_5_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_wall_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_wall_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9665
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9544
# ✅ http://example.org/building/storey_2_column_4 → http://example.org/building/slab_2 | score=0.9214
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/slab_2 | score=0.9151
# ✅ http://example.org/building/storey_2_column_3 → http://example.org/building/slab_2 | score=0.9074
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building94.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9992
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9992
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9991
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9989
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=0.9984
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9935
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building70.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ❌ http://example.org/building/storey_1_column_2 → http://example.org/building/floor_slab | score=0.9955
# ❌ http://example.org/building/storey_1_wall_1 → http://example.org/building/floor_slab | score=0.9437
# ❌ http://example.org/building/storey_1_column_3 → http://example.org/building/floor_slab | score=0.9312
#
#  Accuracy of top-15 predictions: 57.14%
#
# 🔍 Processing: /content/ttl_files/building29.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9996
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9994
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9994
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9993
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9992
# ❌ http://example.org/building/storey_1_column_2 → http://example.org/building/roof_slab | score=0.9916
# ❌ http://example.org/building/storey_1_wall_3 → http://example.org/building/roof_slab | score=0.9832
#
#  Accuracy of top-15 predictions: 77.78%
#
# 🔍 Processing: /content/ttl_files/building68.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building49.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_2_wall_2 → http://example.org/building/slab_2 | score=0.9985
# ✅ http://example.org/building/storey_3_column_2 → http://example.org/building/roof_slab | score=0.9982
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/slab_2 | score=0.9972
# ✅ http://example.org/building/storey_2_column_4 → http://example.org/building/slab_2 | score=0.9971
# ✅ http://example.org/building/storey_2_column_3 → http://example.org/building/slab_2 | score=0.9967
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=0.9959
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=0.9948
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=0.9897
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/roof_slab | score=0.9890
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/slab_2 | score=0.9831
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/slab_2 | score=0.9819
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building1.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/roof_slab | score=0.9999
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/roof_slab | score=0.9999
# ✅ http://example.org/building/storey_2_wall_2 → http://example.org/building/roof_slab | score=0.9999
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9996
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9915
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building36.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_5_column_2 → http://example.org/building/roof_slab | score=0.9453
# ✅ http://example.org/building/storey_5_wall_1 → http://example.org/building/roof_slab | score=0.9335
# ✅ http://example.org/building/storey_5_column_1 → http://example.org/building/roof_slab | score=0.9254
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building42.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/slab_2 | score=0.9967
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/slab_2 | score=0.9941
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/slab_2 | score=0.9938
# ✅ http://example.org/building/storey_2_column_3 → http://example.org/building/slab_2 | score=0.9932
# ✅ http://example.org/building/storey_2_wall_2 → http://example.org/building/slab_2 | score=0.9931
# ❌ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_2 | score=0.9923
# ❌ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_2 | score=0.9791
# ❌ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_2 | score=0.9690
#
#  Accuracy of top-15 predictions: 75.00%
#
# 🔍 Processing: /content/ttl_files/building85.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9470
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9144
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building5.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_4 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_wall_3 → http://example.org/building/roof_slab | score=1.0000
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building55.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9999
# ❌ http://example.org/building/storey_1_wall_1 → http://example.org/building/site | score=0.9934
# ❌ http://example.org/building/storey_1_column_1 → http://example.org/building/site | score=0.9917
#
#  Accuracy of top-15 predictions: 50.00%
#
# 🔍 Processing: /content/ttl_files/building26.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building83.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9994
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9993
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9982
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9981
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=0.9972
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=0.9866
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building58.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_5_wall_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_wall_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_4 → http://example.org/building/roof_slab | score=1.0000
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building90.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_4_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_4_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_4_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9999
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building25.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_5_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_2 → http://example.org/building/roof_slab | score=1.0000
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building38.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9997
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=0.9996
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/slab_3 | score=0.9321
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/slab_2 | score=0.9013
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/slab_3 | score=0.9013
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building12.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9996
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=0.9996
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9994
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9980
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/roof_slab | score=0.9838
# ✅ http://example.org/building/storey_2_wall_3 → http://example.org/building/roof_slab | score=0.9828
# ✅ http://example.org/building/storey_2_wall_2 → http://example.org/building/roof_slab | score=0.9810
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/roof_slab | score=0.9756
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building35.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9996
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9995
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9993
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9986
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9986
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9973
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=0.9946
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building59.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=0.9999
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=0.9999
# ✅ http://example.org/building/storey_3_wall_3 → http://example.org/building/roof_slab | score=0.9999
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=0.9998
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9979
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9972
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/slab_2 | score=0.9655
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/slab_2 | score=0.9647
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=0.9587
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/slab_2 | score=0.9477
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building44.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_2_column_4 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_2_column_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/roof_slab | score=0.9999
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/roof_slab | score=0.9999
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building28.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9996
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9992
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9980
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9966
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building48.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9990
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9985
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9984
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9977
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9934
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/slab_2 | score=0.9918
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/slab_2 | score=0.9907
# ✅ http://example.org/building/storey_2_column_3 → http://example.org/building/slab_2 | score=0.9903
# ✅ http://example.org/building/storey_2_column_4 → http://example.org/building/slab_2 | score=0.9888
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/slab_2 | score=0.9859
# ❌ http://example.org/building/storey_4_wall_2 → http://example.org/building/storey_5 | score=0.9703
# ❌ http://example.org/building/storey_4_column_1 → http://example.org/building/storey_5 | score=0.9272
# ❌ http://example.org/building/storey_4_wall_1 → http://example.org/building/storey_5 | score=0.9215
# ❌ http://example.org/building/storey_4_column_2 → http://example.org/building/storey_5 | score=0.9190
#
#  Accuracy of top-15 predictions: 71.43%
#
# 🔍 Processing: /content/ttl_files/building21.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_3_column_4 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9617
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9173
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building88.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9997
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building71.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ⚠️ Failed to process /content/ttl_files/building71.ttl: division by zero
#
# 🔍 Processing: /content/ttl_files/building61.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9975
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9890
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9861
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building51.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9856
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9793
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9691
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9598
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building54.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ❌ http://example.org/building/storey_1_column_3 → http://example.org/building/site | score=0.9398
#
#  Accuracy of top-15 predictions: 90.00%
#
# 🔍 Processing: /content/ttl_files/building95.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_4_column_3 → http://example.org/building/roof_slab | score=0.9968
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9838
# ✅ http://example.org/building/storey_4_column_2 → http://example.org/building/roof_slab | score=0.9835
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9833
# ✅ http://example.org/building/storey_4_column_1 → http://example.org/building/roof_slab | score=0.9833
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9707
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9653
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building34.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9980
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9957
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9892
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/slab_2 | score=0.9543
# ✅ http://example.org/building/storey_2_wall_2 → http://example.org/building/slab_2 | score=0.9097
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building41.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/slab_2 | score=0.9313
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building97.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9998
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building39.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ⚠️ Failed to process /content/ttl_files/building39.ttl: division by zero
#
# 🔍 Processing: /content/ttl_files/building57.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9994
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9991
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=0.9989
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9989
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9988
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9980
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9959
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building84.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9999
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building11.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9999
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building47.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9997
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/slab_2 | score=0.9908
# ✅ http://example.org/building/storey_2_wall_2 → http://example.org/building/slab_2 | score=0.9903
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/slab_2 | score=0.9866
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/slab_2 | score=0.9842
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building92.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9999
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building18.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9997
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9997
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building3.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building20.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/slab_2 | score=0.9198
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/slab_2 | score=0.9055
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building23.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=0.9994
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9992
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9988
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9976
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9963
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building50.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/roof_slab | score=0.9961
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=0.9945
# ✅ http://example.org/building/storey_3_wall_3 → http://example.org/building/roof_slab | score=0.9942
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=0.9937
# ✅ http://example.org/building/storey_3_column_2 → http://example.org/building/roof_slab | score=0.9935
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=0.9772
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building87.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9997
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/slab_2 | score=0.9846
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/slab_2 | score=0.9799
# ✅ http://example.org/building/storey_2_column_3 → http://example.org/building/slab_2 | score=0.9777
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/slab_2 | score=0.9770
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building56.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_4_wall_1 → http://example.org/building/roof_slab | score=0.9931
# ✅ http://example.org/building/storey_4_column_1 → http://example.org/building/roof_slab | score=0.9827
# ✅ http://example.org/building/storey_4_column_2 → http://example.org/building/roof_slab | score=0.9801
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9382
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9297
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building2.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9995
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building78.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/roof_slab | score=0.9996
# ✅ http://example.org/building/storey_2_column_4 → http://example.org/building/roof_slab | score=0.9995
# ✅ http://example.org/building/storey_2_wall_1 → http://example.org/building/roof_slab | score=0.9995
# ✅ http://example.org/building/storey_2_column_3 → http://example.org/building/roof_slab | score=0.9995
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/roof_slab | score=0.9994
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building77.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ❌ http://example.org/building/storey_3_wall_1 → http://example.org/building/storey_4 | score=0.9997
# ❌ http://example.org/building/storey_3_column_1 → http://example.org/building/storey_4 | score=0.9994
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9991
#
#  Accuracy of top-15 predictions: 75.00%
#
# 🔍 Processing: /content/ttl_files/building98.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9998
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building45.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ❌ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_2 | score=1.0000
# ❌ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_2 | score=0.9998
# ❌ http://example.org/building/storey_6_wall_2 → http://example.org/building/storey_6 | score=0.9977
# ❌ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_2 | score=0.9968
# ...
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/roof_slab | score=0.9597
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=0.9449
# ✅ http://example.org/building/storey_3_column_2 → http://example.org/building/roof_slab | score=0.9231
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=0.9099
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building7.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9321
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9319
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9082
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building10.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9997
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=0.9987
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9986
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9879
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9584
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building82.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9933
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9920
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9899
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9882
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9880
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building30.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9928
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9909
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9875
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9833
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9811
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building43.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ❌ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_2 | score=1.0000
# ❌ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_2 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=1.0000
# ❌ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_2 | score=1.0000
# ❌ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_2 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ❌ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_2 | score=1.0000
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ❌ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_2 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9999
# ❌ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_2 | score=0.9998
# ✅ http://example.org/building/storey_2_column_3 → http://example.org/building/slab_2 | score=0.9912
#
#  Accuracy of top-15 predictions: 53.33%
#
# 🔍 Processing: /content/ttl_files/building19.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9983
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9959
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9959
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9952
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building66.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_3_wall_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_wall_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9885
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9818
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9808
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9761
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9736
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building13.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9999
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building24.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_5_wall_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_wall_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_4 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_5_column_3 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_5_wall_1 → http://example.org/building/roof_slab | score=0.9998
# ✅ http://example.org/building/storey_2_wall_3 → http://example.org/building/slab_2 | score=0.9684
# ✅ http://example.org/building/storey_2_column_1 → http://example.org/building/slab_2 | score=0.9600
# ✅ http://example.org/building/storey_2_column_4 → http://example.org/building/slab_2 | score=0.9556
# ✅ http://example.org/building/storey_2_column_3 → http://example.org/building/slab_2 | score=0.9399
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/slab_2 | score=0.9362
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building93.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9999
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building33.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_4_column_3 → http://example.org/building/roof_slab | score=0.9954
# ✅ http://example.org/building/storey_4_wall_2 → http://example.org/building/roof_slab | score=0.9951
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9915
# ✅ http://example.org/building/storey_4_wall_1 → http://example.org/building/roof_slab | score=0.9891
# ✅ http://example.org/building/storey_4_column_1 → http://example.org/building/roof_slab | score=0.9837
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9448
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building63.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building74.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_4_wall_1 → http://example.org/building/roof_slab | score=0.9920
# ✅ http://example.org/building/storey_4_column_2 → http://example.org/building/roof_slab | score=0.9741
# ✅ http://example.org/building/storey_4_column_1 → http://example.org/building/roof_slab | score=0.9725
# ✅ http://example.org/building/storey_4_column_3 → http://example.org/building/roof_slab | score=0.9501
# ✅ http://example.org/building/storey_3_column_4 → http://example.org/building/slab_3 | score=0.9248
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/slab_3 | score=0.9103
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building52.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9999
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9998
# ✅ http://example.org/building/storey_3_column_3 → http://example.org/building/roof_slab | score=0.9504
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building91.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_3_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_3_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9974
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9966
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9947
# ✅ http://example.org/building/storey_2_column_2 → http://example.org/building/slab_2 | score=0.9050
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building40.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=1.0000
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building96.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=1.0000
# ✅ http://example.org/building/storey_4_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_4_column_1 → http://example.org/building/roof_slab | score=0.9995
#
#  Accuracy of top-15 predictions: 100.00%
#
# 🔍 Processing: /content/ttl_files/building15.ttl
# 📊 Top 15 predicted missing `botAiLab:supports` links:
# ✅ http://example.org/building/storey_4_wall_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_4_wall_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_4_column_2 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_4_column_1 → http://example.org/building/roof_slab | score=1.0000
# ✅ http://example.org/building/storey_1_column_1 → http://example.org/building/slab_1 | score=0.9989
# ✅ http://example.org/building/storey_1_column_4 → http://example.org/building/slab_1 | score=0.9987
# ✅ http://example.org/building/storey_1_column_2 → http://example.org/building/slab_1 | score=0.9983
# ✅ http://example.org/building/storey_1_wall_1 → http://example.org/building/slab_1 | score=0.9966
# ✅ http://example.org/building/storey_1_column_3 → http://example.org/building/slab_1 | score=0.9949
# ✅ http://example.org/building/storey_1_wall_3 → http://example.org/building/slab_1 | score=0.9884
# ✅ http://example.org/building/storey_1_wall_2 → http://example.org/building/slab_1 | score=0.9398
#
#  Accuracy of top-15 predictions: 100.00%
# Average Acc: 0.9563
