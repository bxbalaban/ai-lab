# %%
# !pip install rdflib torch_geometric

# %%
import os
import torch
import torch.nn.functional as F
from torch import nn
from torch_geometric.data import Data
from torch_geometric.nn import RGCNConv
from torch_geometric.utils import negative_sampling
import rdflib
from rdflib.namespace import Namespace, RDF
from shapely import wkt
import glob
import random
import re
import requests
from sklearn.metrics import precision_score
from rdflib.namespace import NamespaceManager

# %%
OWNER = "bxbalaban"
REPO = "ai-lab"
BRANCH = "db0c4603d6b5b78929720437b2bbf93ede6ff6b6"
FOLDER_PATH = "data"

os.makedirs("ttl_files", exist_ok=True)

api_url = f"https://api.github.com/repos/{OWNER}/{REPO}/contents/{FOLDER_PATH}?ref={BRANCH}"

response = requests.get(api_url)
response.raise_for_status()
files = response.json()

ttl_files = [f for f in files if f["name"].endswith(".ttl")]

print(f"Found {len(ttl_files)} TTL files.")

for file_info in ttl_files:
    download_url = file_info["download_url"]
    filename = file_info["name"]
    print(f"Downloading {filename} ...")
    r = requests.get(download_url)
    r.raise_for_status()
    with open(os.path.join("ttl_files", filename), "wb") as f:
        f.write(r.content)

print("All TTL files downloaded to ./ttl_files/")
# Out:
# Found 100 TTL files.
# Downloading building1.ttl ...
# Downloading building10.ttl ...
# Downloading building100.ttl ...
# Downloading building11.ttl ...
# Downloading building12.ttl ...
# Downloading building13.ttl ...
# Downloading building14.ttl ...
# Downloading building15.ttl ...
# Downloading building16.ttl ...
# Downloading building17.ttl ...
# Downloading building18.ttl ...
# Downloading building19.ttl ...
# Downloading building2.ttl ...
# Downloading building20.ttl ...
# Downloading building21.ttl ...
# Downloading building22.ttl ...
# Downloading building23.ttl ...
# Downloading building24.ttl ...
# Downloading building25.ttl ...
# Downloading building26.ttl ...
# Downloading building27.ttl ...
# Downloading building28.ttl ...
# Downloading building29.ttl ...
# Downloading building3.ttl ...
# Downloading building30.ttl ...
# Downloading building31.ttl ...
# Downloading building32.ttl ...
# Downloading building33.ttl ...
# Downloading building34.ttl ...
# Downloading building35.ttl ...
# Downloading building36.ttl ...
# Downloading building37.ttl ...
# Downloading building38.ttl ...
# Downloading building39.ttl ...
# Downloading building4.ttl ...
# Downloading building40.ttl ...
# Downloading building41.ttl ...
# Downloading building42.ttl ...
# Downloading building43.ttl ...
# Downloading building44.ttl ...
# Downloading building45.ttl ...
# Downloading building46.ttl ...
# Downloading building47.ttl ...
# Downloading building48.ttl ...
# Downloading building49.ttl ...
# Downloading building5.ttl ...
# Downloading building50.ttl ...
# Downloading building51.ttl ...
# Downloading building52.ttl ...
# Downloading building53.ttl ...
# Downloading building54.ttl ...
# Downloading building55.ttl ...
# Downloading building56.ttl ...
# Downloading building57.ttl ...
# Downloading building58.ttl ...
# Downloading building59.ttl ...
# Downloading building6.ttl ...
# Downloading building60.ttl ...
# Downloading building61.ttl ...
# Downloading building62.ttl ...
# Downloading building63.ttl ...
# Downloading building64.ttl ...
# Downloading building65.ttl ...
# Downloading building66.ttl ...
# Downloading building67.ttl ...
# Downloading building68.ttl ...
# Downloading building69.ttl ...
# Downloading building7.ttl ...
# Downloading building70.ttl ...
# Downloading building71.ttl ...
# Downloading building72.ttl ...
# Downloading building73.ttl ...
# Downloading building74.ttl ...
# Downloading building75.ttl ...
# Downloading building76.ttl ...
# Downloading building77.ttl ...
# Downloading building78.ttl ...
# Downloading building79.ttl ...
# Downloading building8.ttl ...
# Downloading building80.ttl ...
# Downloading building81.ttl ...
# Downloading building82.ttl ...
# Downloading building83.ttl ...
# Downloading building84.ttl ...
# Downloading building85.ttl ...
# Downloading building86.ttl ...
# Downloading building87.ttl ...
# Downloading building88.ttl ...
# Downloading building89.ttl ...
# Downloading building9.ttl ...
# Downloading building90.ttl ...
# Downloading building91.ttl ...
# Downloading building92.ttl ...
# Downloading building93.ttl ...
# Downloading building94.ttl ...
# Downloading building95.ttl ...
# Downloading building96.ttl ...
# Downloading building97.ttl ...
# Downloading building98.ttl ...
# Downloading building99.ttl ...
# All TTL files downloaded to ./ttl_files/

# %%
BOT = Namespace("https://w3id.org/bot#")
BOTAI = Namespace("http://www.aiLab.org/botAiLab#")
GEO = Namespace("http://www.opengis.net/ont/geosparql#")
LOCAL = Namespace("http://example.org/building/")
relation_uris = [
        BOTAI.adjacentElement,
        BOTAI.isAbove,
        BOTAI.intersectsElement
    ]
label_map = {
        BOTAI.Column: 0,
        BOTAI.Slab: 1,
        BOTAI.Wall: 2,
        BOTAI.FloorSlab: 3,
        BOTAI.RoofSlab: 4
    }
inv_label_map = {v: k for k, v in label_map.items()}
target_classes = list(label_map.keys())
num_features = 7

# %%
class GeoNodeClassifier(nn.Module):
    def __init__(self, in_channels, hidden_channels=64):
        super().__init__()
        num_relations = len(relation_uris)
        num_classes = len(label_map)

        self.conv1 = RGCNConv(in_channels, hidden_channels, num_relations)
        self.conv2 = RGCNConv(hidden_channels, hidden_channels, num_relations)
        self.classifier = nn.Linear(hidden_channels, num_classes)

    def forward(self, x, edge_index, edge_type):
        x = self.conv1(x, edge_index, edge_type).relu()
        x = self.conv2(x, edge_index, edge_type).relu()
        return self.classifier(x)

def parse_ttl_to_pyg(ttl_path):
    g = rdflib.Graph()
    g.parse(ttl_path, format="turtle")
    g.bind("botAiLab", BOTAI)
    g.bind("geo", GEO)

    nodes = list(set(
        s for cls in target_classes
        for s in g.subjects(RDF.type, cls)
    ))
    node_idx = {n: i for i, n in enumerate(nodes)}
    num_nodes = len(nodes)

    features = torch.zeros((num_nodes, num_features))
    labels = torch.full((num_nodes,), -1, dtype=torch.long)  # -1 means unlabeled

    for s in nodes:
        i = node_idx[s]

        # Features
        loc = g.value(s, GEO.asWKT)
        if loc:
            pt = wkt.loads(str(loc))
            features[i][:3] = torch.tensor([pt.x, pt.y, getattr(pt, 'z', 0.0)])

        size = g.value(s, BOTAI.hasSize)
        if size:
            try:
                w, h, d = map(float, str(size).split(","))
                features[i][3:6] = torch.tensor([w, h, d])
            except:
                pass

        rot = g.value(s, BOTAI.hasRotation)
        if rot:
            try:
                features[i][6] = float(str(rot))
            except:
                pass

        # Label
        for label_uri, label_id in label_map.items():
          if (s, RDF.type, label_uri) in g:
              labels[i] = label_id
              break

    relation_to_id = {rel: i for i, rel in enumerate(relation_uris)}

    edge_list = []
    edge_types = []
    for rel in relation_uris:
        for s, _, o in g.triples((None, rel, None)):
            if s in node_idx and o in node_idx:
                edge_list.append([node_idx[s], node_idx[o]])
                edge_types.append(relation_to_id[rel])

    if not edge_list:
        edge_index = torch.empty((2, 0), dtype=torch.long)
        edge_type = torch.empty((0,), dtype=torch.long)
    else:
        edge_index = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
        edge_type = torch.tensor(edge_types, dtype=torch.long)

    return Data(x=features, edge_index=edge_index, edge_type=edge_type, y=labels)


def train(model, data, optimizer):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index, data.edge_type)
    mask = data.y >= 0  # Only use labeled nodes
    loss = F.cross_entropy(out[mask], data.y[mask])
    loss.backward()
    optimizer.step()
    return loss.item()

def main(data_folder, epochs=200):
    ttl_files = glob.glob(os.path.join(data_folder, "*.ttl"))

    filtered_files = []
    for f in ttl_files:
        filename = os.path.basename(f)
        match = re.search(r'(\d+)\.ttl$', filename)
        if match:
            num = int(match.group(1))
            if 1 <= num <= 100:
                filtered_files.append(f)

    all_graphs = [parse_ttl_to_pyg(f) for f in filtered_files]

    model = GeoNodeClassifier(in_channels=7)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

    for epoch in range(1, epochs + 1):
        total_loss = 0
        for graph in all_graphs:
            loss = train(model, graph, optimizer)
            total_loss += loss
        print(f"Epoch {epoch} - Loss: {total_loss:.4f}")

    torch.save(model.state_dict(), "node_classifier_model.pt")
    print("✅ Model saved to node_classifier_model.pt")

if __name__ == "__main__":
    main(data_folder="/content/ttl_files")
# Out:
# Epoch 1 - Loss: 108.6397
# Epoch 2 - Loss: 85.9473
# Epoch 3 - Loss: 82.1802
# Epoch 4 - Loss: 79.8025
# Epoch 5 - Loss: 79.9395
# Epoch 6 - Loss: 80.0387
# Epoch 7 - Loss: 75.0152
# Epoch 8 - Loss: 72.6111
# Epoch 9 - Loss: 70.6900
# Epoch 10 - Loss: 68.4323
# Epoch 11 - Loss: 67.7909
# Epoch 12 - Loss: 67.0191
# Epoch 13 - Loss: 66.5601
# Epoch 14 - Loss: 64.2763
# Epoch 15 - Loss: 63.2816
# Epoch 16 - Loss: 62.9693
# Epoch 17 - Loss: 62.5248
# Epoch 18 - Loss: 62.5607
# Epoch 19 - Loss: 61.0814
# Epoch 20 - Loss: 62.0559
# Epoch 21 - Loss: 62.6438
# Epoch 22 - Loss: 61.6204
# Epoch 23 - Loss: 60.9812
# Epoch 24 - Loss: 60.3101
# Epoch 25 - Loss: 60.1776
# Epoch 26 - Loss: 62.8940
# Epoch 27 - Loss: 62.5150
# Epoch 28 - Loss: 61.4219
# Epoch 29 - Loss: 60.6782
# Epoch 30 - Loss: 60.4483
# Epoch 31 - Loss: 60.5744
# Epoch 32 - Loss: 60.7576
# Epoch 33 - Loss: 58.8297
# Epoch 34 - Loss: 59.1655
# Epoch 35 - Loss: 61.0453
# Epoch 36 - Loss: 59.8402
# Epoch 37 - Loss: 61.7822
# Epoch 38 - Loss: 59.2249
# Epoch 39 - Loss: 61.4524
# Epoch 40 - Loss: 60.5845
# Epoch 41 - Loss: 61.4962
# Epoch 42 - Loss: 61.2684
# ✅ Model saved to node_classifier_model.pt

# %%
def load_graph_for_inference(ttl_file):
    g = rdflib.Graph()
    g.parse(ttl_file, format="turtle")
    g.bind("botAiLab", BOTAI)
    g.bind("geo", GEO)

    nodes = list(set(g.subjects()))
    node_index = {n: i for i, n in enumerate(nodes)}
    index_node = {i: n for n, i in node_index.items()}
    num_nodes = len(nodes)

    features = torch.zeros((num_nodes, num_features))

    for s in nodes:
        loc = g.value(s, BOTAI.hasLocation)
        if loc:
            try:
                coords = list(map(float, str(loc).split(",")))
                if len(coords) == 3:
                    x, y, z = coords
                    wkt_str = f"POINT Z({x} {y} {z})"
                    g.add((s, GEO.asWKT, rdflib.Literal(wkt_str, datatype=GEO.wktLiteral)))
            except:
                continue

    for s in nodes:
        i = node_index[s]
        loc = g.value(s, GEO.asWKT)
        if loc:
            pt = wkt.loads(str(loc))
            features[i][:3] = torch.tensor([pt.x, pt.y, getattr(pt, 'z', 0.0)])

        size = g.value(s, BOTAI.hasSize)
        if size:
            try:
                w, h, d = map(float, str(size).split(","))
                features[i][3:6] = torch.tensor([w, h, d])
            except:
                pass

        rot = g.value(s, BOTAI.hasRotation)
        if rot:
            try:
                features[i][6] = float(str(rot))
            except:
                pass

    relation_to_id = {rel: i for i, rel in enumerate(relation_uris)}

    edge_list = []
    edge_types = []

    for rel in relation_uris:
        for s, _, o in g.triples((None, rel, None)):
            if s in node_index and o in node_index:
                edge_list.append([node_index[s], node_index[o]])
                edge_types.append(relation_to_id[rel])

    if not edge_list:
        edge_index = torch.empty((2, 0), dtype=torch.long)
        edge_type = torch.empty((0,), dtype=torch.long)
    else:
        edge_index = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
        edge_type = torch.tensor(edge_types, dtype=torch.long)

    return Data(x=features, edge_index=edge_index, edge_type=edge_type), index_node

# %%
def predict_node_classes(ttl_file, model_path):
    original_graph = rdflib.Graph()
    original_graph.parse(ttl_file, format="turtle")

    target_nodes = {}
    target_classes.append(BOT.Element)
    for cls in target_classes:
        for s in original_graph.subjects(RDF.type, cls):
            target_nodes[s] = cls

    if not target_nodes:
        print("🚫 No target-class nodes found.")
        return

    for node, original_class in target_nodes.items():
        original_graph.remove((node, RDF.type, original_class))
        original_graph.add((node, RDF.type, BOT.Element))

    temp_ttl = "temp_elementized.ttl"
    original_graph.serialize(temp_ttl, format="turtle")

    data, index_node = load_graph_for_inference(temp_ttl)
    node_index = {v: k for k, v in index_node.items()}

    element_indices = [
        node_index[s] for s in target_nodes.keys() if s in node_index
    ]
    if not element_indices:
        print("🚫 No valid bot:Element nodes found in graph.")
        return

    model = GeoNodeClassifier(in_channels=num_features)
    model.load_state_dict(torch.load(model_path, map_location=torch.device("cpu")))
    model.eval()

    with torch.no_grad():
        logits = model(data.x, data.edge_index, data.edge_type)
        predictions = logits.argmax(dim=1)

    # Compare predictions to original class labels
    correct = 0
    total = 0
    print("📊 Predictions on bot:Element nodes:")
    for idx in element_indices:
        node_uri = rdflib.URIRef(index_node[idx])
        pred_class = predictions[idx].item()
        predicted_uri = inv_label_map[pred_class]
        original_uri = target_nodes.get(node_uri)

        # Add predicted class triple
        original_graph.add((node_uri, RDF.type, predicted_uri))

        # Accuracy check
        if original_uri == predicted_uri:
            correct += 1
        total += 1

        print(f"{node_uri} → Predicted: {predicted_uri.split('#')[-1]}, "
              f"Original: {original_uri.split('#')[-1]}")

    accuracy = correct / total if total > 0 else 0
    print(f"\n✅ Classification accuracy: {accuracy:.2%}")

    # Save updated TTL
    folder = os.path.dirname(ttl_file)
    filename = os.path.basename(ttl_file)
    enriched_path = os.path.join(folder, f"classified_{filename}")

    namespace_manager = NamespaceManager(original_graph)
    namespace_manager.bind("botAiLab", BOTAI)
    namespace_manager.bind("bot", BOT)
    namespace_manager.bind("local", LOCAL)
    original_graph.namespace_manager = namespace_manager
    original_graph.serialize(destination=enriched_path, format="turtle")

    print(f"✅ Enriched TTL saved to: {enriched_path}")
    return accuracy

# %%
def predict_node_classes_in_folder(folder_path, model_path):
    ttl_files = glob.glob(os.path.join(folder_path, "*.ttl"))

    filtered_files = []
    for f in ttl_files:
        filename = os.path.basename(f)
        match = re.search(r'^building(\d+)\.ttl$', filename)
        if match:
            num = int(match.group(1))
            if 1 <= num <= 100:
                filtered_files.append(f)

    if not filtered_files:
        print("🚫 No TTL files found in the folder.")
        return

    accuracies = []
    for ttl_file in filtered_files:
        full_path = os.path.join(folder_path, ttl_file)
        print(f"\n🔍 Processing: {ttl_file}")
        try:
            acc = predict_node_classes(
                ttl_file=full_path,
                model_path=model_path
            )
            if acc is not None:
                accuracies.append(acc)
        except Exception as e:
            print(f"⚠️ Failed to classify {ttl_file}: {e}")

    if accuracies:
        avg_acc = sum(accuracies) / len(accuracies)
        print(f"\n📊 Average accuracy over {len(accuracies)} files: {avg_acc:.2%}")
    else:
        print("\n🚫 No accuracy could be computed.")

# %%
predict_node_classes_in_folder(
    folder_path="/content/ttl_files",
    model_path="/content/node_classifier_model.pt"
)
# Out:
# 🔍 Processing: /content/ttl_files/building14.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_5_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_4 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_5_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 78.95%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building14.ttl
#
# 🔍 Processing: /content/ttl_files/building78.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Wall, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 84.62%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building78.ttl
#
# 🔍 Processing: /content/ttl_files/building13.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_4 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_5_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 78.26%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building13.ttl
#
# 🔍 Processing: /content/ttl_files/building52.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Wall, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_3 → Predicted: Column, Original: Column
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 90.00%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building52.ttl
#
# 🔍 Processing: /content/ttl_files/building44.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 90.91%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building44.ttl
#
# 🔍 Processing: /content/ttl_files/building6.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 68.18%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building6.ttl
#
# 🔍 Processing: /content/ttl_files/building15.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Wall, Original: Column
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: FloorSlab, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 83.33%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building15.ttl
#
# 🔍 Processing: /content/ttl_files/building25.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_3 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_4 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 80.77%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building25.ttl
#
# 🔍 Processing: /content/ttl_files/building43.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_3 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 84.62%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building43.ttl
#
# 🔍 Processing: /content/ttl_files/building65.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Column, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 85.71%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building65.ttl
#
# 🔍 Processing: /content/ttl_files/building40.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Wall, Original: Column
# http://example.org/building/storey_2_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 84.21%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building40.ttl
#
# 🔍 Processing: /content/ttl_files/building11.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 88.24%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building11.ttl
#
# 🔍 Processing: /content/ttl_files/building73.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_2_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Wall, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Wall, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_1 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/floor_slab → Predicted: Slab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 69.57%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building73.ttl
#
# 🔍 Processing: /content/ttl_files/building36.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_3_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_2 → Predicted: Column, Original: Column
# http://example.org/building/slab_4 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_3_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 89.66%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building36.ttl
#
# 🔍 Processing: /content/ttl_files/building99.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 93.75%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building99.ttl
#
# 🔍 Processing: /content/ttl_files/building56.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 76.47%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building56.ttl
#
# 🔍 Processing: /content/ttl_files/building23.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_3 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_4 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_3 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_4_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_3_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 81.82%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building23.ttl
#
# 🔍 Processing: /content/ttl_files/building20.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Wall, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 80.95%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building20.ttl
#
# 🔍 Processing: /content/ttl_files/building82.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/storey_3_column_3 → Predicted: RoofSlab, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_4_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Column, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 73.08%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building82.ttl
#
# 🔍 Processing: /content/ttl_files/building79.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_4 → Predicted: Wall, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_4 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_3 → Predicted: Column, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_4_wall_3 → Predicted: Column, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 75.00%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building79.ttl
#
# 🔍 Processing: /content/ttl_files/building10.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_4 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 82.14%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building10.ttl
#
# 🔍 Processing: /content/ttl_files/building22.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Column, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 92.31%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building22.ttl
#
# 🔍 Processing: /content/ttl_files/building63.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_3_wall_3 → Predicted: Column, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 70.00%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building63.ttl
#
# 🔍 Processing: /content/ttl_files/building26.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_4 → Predicted: Wall, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: Slab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 80.00%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building26.ttl
#
# 🔍 Processing: /content/ttl_files/building18.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Column, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 78.57%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building18.ttl
#
# 🔍 Processing: /content/ttl_files/building9.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Wall, Original: Column
# http://example.org/building/storey_4_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_4_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: FloorSlab, Original: Wall
# ...
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_3_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 82.61%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building69.ttl
#
# 🔍 Processing: /content/ttl_files/building97.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_2_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/floor_slab → Predicted: Slab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 71.43%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building97.ttl
#
# 🔍 Processing: /content/ttl_files/building35.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 85.71%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building35.ttl
#
# 🔍 Processing: /content/ttl_files/building12.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Slab, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: Slab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 53.85%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building12.ttl
#
# 🔍 Processing: /content/ttl_files/building48.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_5_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Wall, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_4 → Predicted: Wall, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_3 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_4 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_4_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 83.87%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building48.ttl
#
# 🔍 Processing: /content/ttl_files/building17.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 93.33%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building17.ttl
#
# 🔍 Processing: /content/ttl_files/building91.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: Slab, Original: Slab
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: RoofSlab, Original: RoofSlab
#
# ✅ Classification accuracy: 93.33%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building91.ttl
#
# 🔍 Processing: /content/ttl_files/building61.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_2_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_2 → Predicted: Column, Original: Column
# http://example.org/building/slab_4 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_3 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_3_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Column, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/storey_5_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/floor_slab → Predicted: FloorSlab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 77.42%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building61.ttl
#
# 🔍 Processing: /content/ttl_files/building71.ttl
# 📊 Predictions on bot:Element nodes:
# http://example.org/building/storey_1_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_3_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_1_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_2 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_3 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_4 → Predicted: Column, Original: Column
# http://example.org/building/storey_5_column_1 → Predicted: Wall, Original: Column
# http://example.org/building/storey_2_column_1 → Predicted: Column, Original: Column
# http://example.org/building/storey_4_column_1 → Predicted: Column, Original: Column
# http://example.org/building/slab_4 → Predicted: Slab, Original: Slab
# http://example.org/building/slab_3 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_1 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/slab_2 → Predicted: FloorSlab, Original: Slab
# http://example.org/building/storey_3_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_1_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_3_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_3 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_5_wall_1 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_2_wall_2 → Predicted: Wall, Original: Wall
# http://example.org/building/storey_4_wall_1 → Predicted: Column, Original: Wall
# http://example.org/building/floor_slab → Predicted: Slab, Original: FloorSlab
# http://example.org/building/roof_slab → Predicted: Slab, Original: RoofSlab
#
# ✅ Classification accuracy: 75.86%
# ✅ Enriched TTL saved to: /content/ttl_files/classified_building71.ttl
#
# 📊 Average accuracy over 100 files: 80.05%
